# %%
using FakeGeno
using ProfileView

# %%
make_pop(1000,100,5); #compile?
# Out:
# ...
# generate sample population ....
#
# # inidviduals  : 100
# # chromosomes  : 200
# # SNPs         : 1000
# # generations  : 800   (4.0 x char. decay)
# # hotspots     : 5
#
# mutationrate set to 0.002891391445976558
# corresponding to average heterozygosity : 0.35
# ...
# 1000x200 Array{Bool,2}:
#  false  false  false  false   true  …  false  false   true  false   true
#  false  false  false   true  false     false  false  false   true  false
#  false   true   true  false  false     false  false  false  false  false
#  false   true   true   true   true      true   true   true   true   true
#   true   true   true   true   true      true   true   true   true   true
#  false  false  false  false   true  …  false  false  false  false  false
#  false  false  false   true  false     false  false  false   true  false
#   true   true   true   true  false      true   true   true   true   true
#   true   true   true   true   true      true   true  false   true   true
# ...

# %%
Nsnp = 1000
Nind = 1000
Nhs = 10

@time make_pop(Nsnp,Nind,Nhs);
Profile.clear()
@profile make_pop(Nsnp,Nind,Nhs);
ProfileView.view()
# Out:
# ...
# generate sample population ....
#
# # inidviduals  : 1000
# # chromosomes  : 2000
# # SNPs         : 1000
# # generations  : 8000   (4.0 x char. decay)
# # hotspots     : 10
#
# mutationrate set to 0.00029141170619945833
# corresponding to average heterozygosity : 0.35
# ...
# 136.261611 seconds (279.26 M allocations: 157.405 GB, 13.20% gc time)
# ...
# generate sample population ....
#
# # inidviduals  : 1000
# # chromosomes  : 2000
# # SNPs         : 1000
# # generations  : 8000   (4.0 x char. decay)
# # hotspots     : 10
#
# mutationrate set to 0.00029141170619945833
# corresponding to average heterozygosity : 0.35
# ...
# WARNING: The profile data buffer is full; profiling probably terminated
# before your program finished. To profile for longer runs, call Profile.init
# with a larger buffer and/or larger delay.
# ProfileView.ProfileData(8831x13 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}:
#  RGB{U8}(1.0,1.0,1.0)       RGB{U8}(1.0,1.0,1.0)      …  RGB{U8}(1.0,1.0,1.0)
# ...
